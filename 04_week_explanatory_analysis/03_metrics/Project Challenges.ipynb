# %% [markdown]
# # Week 4 - METRICS AND KPIS - 31.01

# %% [markdown]
# ## Project Challenges: 31.01

# %% [markdown]
# Project Challenges: Error Metrics on a naive forecast

# %% [markdown]
# With regard to the bikes dataset a ’naive’ forecast would be to use the count from the year before to predict the next year. Use the count from May 2011 as a forecast for May 2012 and check how far off the predictions are:

# %%
import pandas as pd

# %%
bike_data = pd.read_csv('../data/bikes_clean.csv', parse_dates=True, index_col=0)
bike_data.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  \
# datetime
# 2011-01-01 00:00:00        81        0.0     3.0        13.0     16
# 2011-01-01 01:00:00        80        0.0     8.0        32.0     40
# 2011-01-01 02:00:00        80        0.0     5.0        27.0     32
# 2011-01-01 03:00:00        75        0.0     3.0        10.0     13
# 2011-01-01 04:00:00        75        0.0     0.0         1.0      1
#
#                      hour_of_day  month  year part_of_day
# datetime
# 2011-01-01 00:00:00            0      1  2011     morning
# 2011-01-01 01:00:00            1      1  2011     morning
# 2011-01-01 02:00:00            2      1  2011     morning
# 2011-01-01 03:00:00            3      1  2011     morning
# 2011-01-01 04:00:00            4      1  2011     morning

# %%
bike_data.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  \
# datetime
# 2011-01-01 00:00:00        81        0.0     3.0        13.0     16
# 2011-01-01 01:00:00        80        0.0     8.0        32.0     40
# 2011-01-01 02:00:00        80        0.0     5.0        27.0     32
# 2011-01-01 03:00:00        75        0.0     3.0        10.0     13
# 2011-01-01 04:00:00        75        0.0     0.0         1.0      1
#
#                      hour_of_day  month  year part_of_day
# datetime
# 2011-01-01 00:00:00            0      1  2011     morning
# 2011-01-01 01:00:00            1      1  2011     morning
# 2011-01-01 02:00:00            2      1  2011     morning
# 2011-01-01 03:00:00            3      1  2011     morning
# 2011-01-01 04:00:00            4      1  2011     morning

# %%
#1.Filter the dataset for May 2011 and the count column
mask = (bike_data['month'] == 5 )
bike_data[mask]
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-05-01 00:00:00       2        0           0        1  17.22  21.210
# 2011-05-01 01:00:00       2        0           0        1  17.22  21.210
# 2011-05-01 02:00:00       2        0           0        1  17.22  21.210
# 2011-05-01 03:00:00       2        0           0        1  16.40  20.455
# 2011-05-01 04:00:00       2        0           0        1  16.40  20.455
# ...                     ...      ...         ...      ...    ...     ...
# 2012-05-31 19:00:00       2        0           1        1  29.52  32.575
# 2012-05-31 20:00:00       2        0           1        1  27.88  31.820
# 2012-05-31 21:00:00       2        0           1        1  27.88  31.820
# 2012-05-31 22:00:00       2        0           1        1  27.06  31.060
# 2012-05-31 23:00:00       2        0           1        1  27.06  31.060
#
#                      humidity  windspeed  casual  registered  count  \
# datetime
# 2011-05-01 00:00:00        67     6.0032    19.0        77.0     96
# 2011-05-01 01:00:00        69     7.0015     9.0        50.0     59
# 2011-05-01 02:00:00        77     7.0015     7.0        43.0     50
# 2011-05-01 03:00:00        82     7.0015     8.0        15.0     23
# 2011-05-01 04:00:00        76     7.0015     6.0        11.0     17
# ...                       ...        ...     ...         ...    ...
# 2012-05-31 19:00:00        34    11.0014     NaN         NaN    420
# 2012-05-31 20:00:00        44    11.0014     NaN         NaN    336
# 2012-05-31 21:00:00        44    11.0014     NaN         NaN    249
# 2012-05-31 22:00:00        50    11.0014     NaN         NaN    188
# 2012-05-31 23:00:00        54    15.0013     NaN         NaN    135
#
#                      hour_of_day  month  year part_of_day
# datetime
# 2011-05-01 00:00:00            0      5  2011     morning
# 2011-05-01 01:00:00            1      5  2011     morning
# 2011-05-01 02:00:00            2      5  2011     morning
# 2011-05-01 03:00:00            3      5  2011     morning
# 2011-05-01 04:00:00            4      5  2011     morning
# ...                          ...    ...   ...         ...
# 2012-05-31 19:00:00           19      5  2012       night
# 2012-05-31 20:00:00           20      5  2012       night
# 2012-05-31 21:00:00           21      5  2012       night
# 2012-05-31 22:00:00           22      5  2012       night
# 2012-05-31 23:00:00           23      5  2012       night
#
# [1488 rows x 15 columns]

# %%
mask = (bike_data['year']== 2011)
bike_data[mask]
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2011-12-31 19:00:00       1        0           0        1  17.22  21.210
# 2011-12-31 20:00:00       1        0           0        1  17.22  21.210
# 2011-12-31 21:00:00       1        0           0        1  16.40  20.455
# 2011-12-31 22:00:00       1        0           0        1  15.58  19.695
# 2011-12-31 23:00:00       1        0           0        1  14.76  18.940
#
#                      humidity  windspeed  casual  registered  count  \
# datetime
# 2011-01-01 00:00:00        81     0.0000     3.0        13.0     16
# 2011-01-01 01:00:00        80     0.0000     8.0        32.0     40
# 2011-01-01 02:00:00        80     0.0000     5.0        27.0     32
# 2011-01-01 03:00:00        75     0.0000     3.0        10.0     13
# 2011-01-01 04:00:00        75     0.0000     0.0         1.0      1
# ...                       ...        ...     ...         ...    ...
# 2011-12-31 19:00:00        54    15.0013     NaN         NaN    131
# 2011-12-31 20:00:00        54    15.0013     NaN         NaN    105
# 2011-12-31 21:00:00        58    12.9980     NaN         NaN     91
# 2011-12-31 22:00:00        62     8.9981     NaN         NaN     76
# 2011-12-31 23:00:00        66     0.0000     NaN         NaN     68
#
#                      hour_of_day  month  year part_of_day
# datetime
# 2011-01-01 00:00:00            0      1  2011     morning
# 2011-01-01 01:00:00            1      1  2011     morning
# 2011-01-01 02:00:00            2      1  2011     morning
# 2011-01-01 03:00:00            3      1  2011     morning
# 2011-01-01 04:00:00            4      1  2011     morning
# ...                          ...    ...   ...         ...
# 2011-12-31 19:00:00           19     12  2011       night
# 2011-12-31 20:00:00           20     12  2011       night
# 2011-12-31 21:00:00           21     12  2011       night
# 2011-12-31 22:00:00           22     12  2011       night
# 2011-12-31 23:00:00           23     12  2011       night
#
# [8645 rows x 15 columns]

# %%
mask = (bike_data['month'] == 5) & (bike_data['count']== 2011)
bike_data[mask]
# Out:
# Empty DataFrame
# Columns: [season, holiday, workingday, weather, temp, atemp, humidity, windspeed, casual, registered, count, hour_of_day, month, year, part_of_day]
# Index: []

# %%
mask = (bike_data['month'] == 5) & (bike_data['year']== 2011)
bike_data[mask]
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-05-01 00:00:00       2        0           0        1  17.22  21.210
# 2011-05-01 01:00:00       2        0           0        1  17.22  21.210
# 2011-05-01 02:00:00       2        0           0        1  17.22  21.210
# 2011-05-01 03:00:00       2        0           0        1  16.40  20.455
# 2011-05-01 04:00:00       2        0           0        1  16.40  20.455
# ...                     ...      ...         ...      ...    ...     ...
# 2011-05-31 19:00:00       2        0           1        1  31.98  37.120
# 2011-05-31 20:00:00       2        0           1        1  31.98  37.120
# 2011-05-31 21:00:00       2        0           1        1  31.16  36.365
# 2011-05-31 22:00:00       2        0           1        1  30.34  34.850
# 2011-05-31 23:00:00       2        0           1        1  29.52  34.850
#
#                      humidity  windspeed  casual  registered  count  \
# datetime
# 2011-05-01 00:00:00        67     6.0032    19.0        77.0     96
# 2011-05-01 01:00:00        69     7.0015     9.0        50.0     59
# 2011-05-01 02:00:00        77     7.0015     7.0        43.0     50
# 2011-05-01 03:00:00        82     7.0015     8.0        15.0     23
# 2011-05-01 04:00:00        76     7.0015     6.0        11.0     17
# ...                       ...        ...     ...         ...    ...
# 2011-05-31 19:00:00        62     7.0015     NaN         NaN    407
# 2011-05-31 20:00:00        62     7.0015     NaN         NaN    310
# 2011-05-31 21:00:00        66     7.0015     NaN         NaN    224
# 2011-05-31 22:00:00        70    11.0014     NaN         NaN    160
# 2011-05-31 23:00:00        79     6.0032     NaN         NaN     98
#
#                      hour_of_day  month  year part_of_day
# datetime
# 2011-05-01 00:00:00            0      5  2011     morning
# 2011-05-01 01:00:00            1      5  2011     morning
# 2011-05-01 02:00:00            2      5  2011     morning
# 2011-05-01 03:00:00            3      5  2011     morning
# 2011-05-01 04:00:00            4      5  2011     morning
# ...                          ...    ...   ...         ...
# 2011-05-31 19:00:00           19      5  2011       night
# 2011-05-31 20:00:00           20      5  2011       night
# 2011-05-31 21:00:00           21      5  2011       night
# 2011-05-31 22:00:00           22      5  2011       night
# 2011-05-31 23:00:00           23      5  2011       night
#
# [744 rows x 15 columns]

# %%
#1.Filter the dataset for May 2011 and the count column
#mask = (bike_data['month'] == 5 & bike_data['year']== 2011 )
#bike_data_May11 = [mask][['count']]

bike_data = (bike_data['month'] == 5) & (bike_data['year']== 2011).isin(['count'])

# %%
bike_data
# Out:
# datetime
# 2011-01-01 00:00:00    False
# 2011-01-01 01:00:00    False
# 2011-01-01 02:00:00    False
# 2011-01-01 03:00:00    False
# 2011-01-01 04:00:00    False
#                        ...
# 2012-12-31 19:00:00    False
# 2012-12-31 20:00:00    False
# 2012-12-31 21:00:00    False
# 2012-12-31 22:00:00    False
# 2012-12-31 23:00:00    False
# Length: 17379, dtype: bool

# %%
#2.Filter the dataset for May 2012 and the count column
bike_data['count'].mean()
# Out:
# 188.61269348063755

# %%
#3.Use the above results as the input for rmse

# %%
#4.How far off on average was this naive prediction?
