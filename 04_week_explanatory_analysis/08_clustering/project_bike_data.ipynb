# %% [markdown]
# # Week 4

# %% [markdown]
# Chapter 4 - Explanatory Analysis

# %% [markdown]
# -PROJECT: BIKE DATA

# %% [markdown]
# Project Description
#
# Capital Bikeshare would like to find out how many bicycles need to be ready at a given time in the Washington, D.C. market

# %% [markdown]
#  + Goal: Explore DC bike data to understand the demand for bicycle rentals over time and fit a regression line to the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/dc_bikes.csv')

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0     3.0        13.0     16
# 1        80        0.0     8.0        32.0     40
# 2        80        0.0     5.0        27.0     32
# 3        75        0.0     3.0        10.0     13
# 4        75        0.0     0.0         1.0      1

# %%
df = pd.read_csv('../data/dc_bikes.csv', parse_dates=True)
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 17374  2012-12-31 19:00:00       1        0           1        2  10.66
# 17375  2012-12-31 20:00:00       1        0           1        2  10.66
# 17376  2012-12-31 21:00:00       1        0           1        1  10.66
# 17377  2012-12-31 22:00:00       1        0           1        1  10.66
# 17378  2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df = pd.read_csv('../data/dc_bikes.csv', parse_dates=True, index_col=0)
df
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed  casual  registered  count
# datetime
# ...

# %%
bk_data_2016 = pd.read_csv('../data/2016Q1-capitalbikeshare-tripdata.csv', parse_dates=True, index_col=0)
bk_data_2016
# Out:
#                    Start date             End date  Start station number  \
# Duration
# 166       2016-01-01 00:06:58  2016-01-01 00:09:44                 31102
# 448       2016-01-01 00:10:20  2016-01-01 00:17:48                 32039
# 715       2016-01-01 00:13:52  2016-01-01 00:25:48                 31222
# 213       2016-01-01 00:15:29  2016-01-01 00:19:03                 31506
# 872       2016-01-01 00:16:16  2016-01-01 00:30:49                 31041
# ...                       ...                  ...                   ...
# 967       2016-03-31 23:57:42  2016-04-01 00:13:49                 31266
# 534       2016-03-31 23:57:51  2016-04-01 00:06:46                 31222
# 301       2016-03-31 23:59:18  2016-04-01 00:04:20                 31280
# 557       2016-03-31 23:59:38  2016-04-01 00:08:56                 31275
# 555       2016-03-31 23:59:42  2016-04-01 00:08:58                 31101
#
#                              Start station  End station number  \
# Duration
# ...

# %%
bk_data_2016.columns
# Out:
# Index(['Start date', 'End date', 'Start station number', 'Start station',
#        'End station number', 'End station', 'Bike number', 'Member type'],
#       dtype='object')

# %%
bk_data_2017 = pd.read_csv('../data/2017Q1-capitalbikeshare-tripdata.csv', parse_dates=True, index_col=0)
bk_data_2017
# Out:
#                    Start date             End date  Start station number  \
# Duration
# 221       2017-01-01 00:00:41  2017-01-01 00:04:23                 31634
# 1676      2017-01-01 00:06:53  2017-01-01 00:34:49                 31258
# 1356      2017-01-01 00:07:10  2017-01-01 00:29:47                 31289
# 1327      2017-01-01 00:07:22  2017-01-01 00:29:30                 31289
# 1636      2017-01-01 00:07:36  2017-01-01 00:34:52                 31258
# ...                       ...                  ...                   ...
# 687       2017-03-31 23:57:10  2017-04-01 00:08:37                 31404
# 257       2017-03-31 23:57:55  2017-04-01 00:02:13                 31602
# 423       2017-03-31 23:58:34  2017-04-01 00:05:38                 31627
# 1048      2017-03-31 23:59:33  2017-04-01 00:17:02                 31213
# 223       2017-03-31 23:59:43  2017-04-01 00:03:26                 31104
#
#                                         Start station  End station number  \
# ...

# %%
bk_data_2016_17 = pd.merge(left=bk_data_2016, right=bk_data_2017, how='outer', on='Start date')

# %%
bk_data_2016_17
# Out:
#                   Start date           End date_x  Start station number_x  \
# 0        2016-01-01 00:06:58  2016-01-01 00:09:44                 31102.0
# 1        2016-01-01 00:10:20  2016-01-01 00:17:48                 32039.0
# 2        2016-01-01 00:13:52  2016-01-01 00:25:48                 31222.0
# 3        2016-01-01 00:15:29  2016-01-01 00:19:03                 31506.0
# 4        2016-01-01 00:16:16  2016-01-01 00:30:49                 31041.0
# ...                      ...                  ...                     ...
# 1198904  2017-03-31 23:57:10                  NaN                     NaN
# 1198905  2017-03-31 23:57:55                  NaN                     NaN
# 1198906  2017-03-31 23:58:34                  NaN                     NaN
# 1198907  2017-03-31 23:59:33                  NaN                     NaN
# 1198908  2017-03-31 23:59:43                  NaN                     NaN
#
#                           Start station_x  End station number_x  \
# ...

# %%
bk_data_2016_17.head(10)
# Out:
#             Start date           End date_x  Start station number_x  \
# 0  2016-01-01 00:06:58  2016-01-01 00:09:44                 31102.0
# 1  2016-01-01 00:10:20  2016-01-01 00:17:48                 32039.0
# 2  2016-01-01 00:13:52  2016-01-01 00:25:48                 31222.0
# 3  2016-01-01 00:15:29  2016-01-01 00:19:03                 31506.0
# 4  2016-01-01 00:16:16  2016-01-01 00:30:49                 31041.0
# 5  2016-01-01 00:16:18  2016-01-01 00:30:37                 31041.0
# 6  2016-01-01 00:16:36  2016-01-01 00:29:38                 31266.0
# 7  2016-01-01 00:18:10  2016-01-01 00:36:32                 31506.0
# 8  2016-01-01 00:20:15  2016-01-01 00:33:49                 31041.0
# 9  2016-01-01 00:26:16  2016-01-01 00:40:58                 31245.0
#
#                     Start station_x  End station number_x  \
# 0               11th & Kenyon St NW               31105.0
# 1  Old Georgetown Rd & Southwick St               32002.0
# ...

# %%
#bk_data_2016_17.to_csv('../data/bk_data_2016_17.csv', index=False)

# %%
import numpy as np
import pandas as pd
#scikit is an open source data analysis library, and the gold standard for Machine Learning
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
bk_data_2016_17 = pd.read_csv('../data/bk_data_2016_17.csv')
bk_data_2016_17
# Out:
# /var/folders/dg/ffmwbvj93wl0h5xfz7grdy5m0000gn/T/ipykernel_17030/1088918953.py:1: DtypeWarning: Columns (1,3,5,6,7,8,10,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   bk_data_2016_17 = pd.read_csv('../data/bk_data_2016_17.csv')
#                   Start date           End date_x  Start station number_x  \
# 0        2016-01-01 00:06:58  2016-01-01 00:09:44                 31102.0
# 1        2016-01-01 00:10:20  2016-01-01 00:17:48                 32039.0
# 2        2016-01-01 00:13:52  2016-01-01 00:25:48                 31222.0
# 3        2016-01-01 00:15:29  2016-01-01 00:19:03                 31506.0
# 4        2016-01-01 00:16:16  2016-01-01 00:30:49                 31041.0
# ...                      ...                  ...                     ...
# 1198904  2017-03-31 23:57:10                  NaN                     NaN
# 1198905  2017-03-31 23:57:55                  NaN                     NaN
# ...

# %%
bk_data_2016_17.columns
# Out:
# Index(['Start date', 'End date_x', 'Start station number_x', 'Start station_x',
#        'End station number_x', 'End station_x', 'Bike number_x',
#        'Member type_x', 'End date_y', 'Start station number_y',
#        'Start station_y', 'End station number_y', 'End station_y',
#        'Bike number_y', 'Member type_y'],
#       dtype='object')

# %%
bk_data_2016_17.head(10)
# Out:
#             Start date           End date_x  Start station number_x  \
# 0  2016-01-01 00:06:58  2016-01-01 00:09:44                 31102.0
# 1  2016-01-01 00:10:20  2016-01-01 00:17:48                 32039.0
# 2  2016-01-01 00:13:52  2016-01-01 00:25:48                 31222.0
# 3  2016-01-01 00:15:29  2016-01-01 00:19:03                 31506.0
# 4  2016-01-01 00:16:16  2016-01-01 00:30:49                 31041.0
# 5  2016-01-01 00:16:18  2016-01-01 00:30:37                 31041.0
# 6  2016-01-01 00:16:36  2016-01-01 00:29:38                 31266.0
# 7  2016-01-01 00:18:10  2016-01-01 00:36:32                 31506.0
# 8  2016-01-01 00:20:15  2016-01-01 00:33:49                 31041.0
# 9  2016-01-01 00:26:16  2016-01-01 00:40:58                 31245.0
#
#                     Start station_x  End station number_x  \
# 0               11th & Kenyon St NW               31105.0
# 1  Old Georgetown Rd & Southwick St               32002.0
# ...

# %%
bk_data_2016_17['Member type_x'].unique()
# Out:
# array(['Member', 'Casual', nan], dtype=object)

# %%
bk_data_2016_17[bk_data_2016_17['Member type_x']== '2016'].describe()
# Out:
#        Start station number_x  End station number_x  Start station number_y  \
# count                     0.0                   0.0                     0.0
# mean                      NaN                   NaN                     NaN
# std                       NaN                   NaN                     NaN
# min                       NaN                   NaN                     NaN
# 25%                       NaN                   NaN                     NaN
# 50%                       NaN                   NaN                     NaN
# 75%                       NaN                   NaN                     NaN
# max                       NaN                   NaN                     NaN
#
#        End station number_y
# count                   0.0
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
df_iris=sns.load_dataset('iris')

# %%
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
bootstrap_sample = Member_type(frac=1, replace=True)
sample_means_list.append(bootstrap_sample.mean())
sns.displot(sample_means_list, bins=40);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 bootstrap_sample = Member_type(frac=1, replace=True)
#       2 sample_means_list.append(bootstrap_sample.mean())
#       3 sns.displot(sample_means_list, bins=40)
#
# NameError: name 'Member_type' is not defined
